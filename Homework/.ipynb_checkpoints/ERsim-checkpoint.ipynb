# %%
#  File: ERsim.py
#  Description: Use a queue to treat patients at a hospital
#  Student's Name: Charles Lybrand
#  Student's UT EID: cbl652
#  Course Name: CS 313E 
#  Unique Number: 51915
#
#  Date Created: 03/04/2017
#  Date Last Modified: 03/04/2017

# %%
class Queue:
    '''
    FIFO queue abstract data type implemented using lists
    '''
    
    def __init__(self):
        self.items = []
        
    def isEmpty(self):
        return self.items == []
    
    def enqueue(self, item):
        self.items.insert(0,item)
        
    def dequeue(self):
        return self.items.pop()
        
    def size(self):
        return len(self.items)
    
    def peek(self):
        return self.items[-1]
    
    def __str__(self):
        return str(self.items)

# %%
def readFile(fileName, critQ, serQ, fairQ):
    '''
    Read in the file and process each line using helper functions
    '''
    
    inFile = open(fileName, "r")
    
    # go through all the lines and apply the correct function
    for line in inFile:
        line = line.split()
        # the action is always the first word
        action = line[0]
        
        # adding a patient
        if(action == "add"):
            # line[1]: patient name, line[2]: patient condition
            handleAdd(line[1], line[2], critQ, serQ, fairQ)
            
        # treating a patient
        elif(action == "treat"):
            # line[1]: condition type
            handleTreat(line[1], critQ, serQ, fairQ)
            
        # exiting the program
        elif(action == "exit"):
            exit()
            return
    
    infile.close()
    return

# %%
def handleAdd(patient, condition, critQ, serQ, fairQ):
    '''
    add patient to the appropriate queue
    '''
    
    print()
    print("Add patient %s to %s queue" % (patient, condition))
    # handle which queue the patient is added to
    if(condition == "Critical"):
        critQ.enqueue(patient)
    elif(condition == "Serious"):
        serQ.enqueue(patient)
    elif(condition == "Fair"):
        fairQ.enqueue(patient)
        
    print()
    queuesState(critQ, serQ, fairQ)

# %%
def handleTreat(condition, critQ, serQ, fairQ):
    '''
    treat the next patient, based on the criteria if there is one
    '''

    # general treat next case
    if(condition == "next"):
        print()
        print("Treat next patient")
        print()
        
        # check critical queue first
        if (not critQ.isEmpty()):
            patient = critQ.dequeue()
            print("Treating '%s' from Critical queue" % (patient))
            queuesState(critQ, serQ, fairQ)
            
        # check serious queue next
        elif (not serQ.isEmpty()):
            patient = serQ.dequeue()
            print("Treating '%s' from Serious queue" % (patient))
            queuesState(critQ, serQ, fairQ)
            
        # check fair queue last
        elif (not fairQ.isEmpty()):
            patient = fairQ.dequeue()
            print("Treating '%s' from Fair queue" % (patient))
            queuesState(critQ, serQ, fairQ)
            
        # if all queues are empty, tell the user
        else:
            print("No patients in queues")
            
    # if told to treat all patients
    elif(condition == "all"):
        print()
        print("Treat all patients")
        
        while(not critQ.isEmpty()):
            print()
            patient = critQ.dequeue()
            print("Treating '%s' from Critical queue" % (patient))
            queuesState(critQ, serQ, fairQ)
            
        while(not serQ.isEmpty()):
            print()
            patient = serQ.dequeue()
            print("Treating '%s' from Serious queue" % (patient))
            queuesState(critQ, serQ, fairQ)
            
        while(not fairQ.isEmpty()):
            print()
            patient = fairQ.dequeue()
            print("Treating '%s' from Fair queue" % (patient))
            queuesState(critQ, serQ, fairQ)
            
        print()
        print("No patients in queues")
    
    # if given a specific type to treat
    else:
        print()
        print("Treat next patient on %s queue" % (condition))
        print()
        
        # if treating critical queue
        if (condition == "Critical"):
            # treat next patient in critical queue
            if(not critQ.isEmpty()):
                patient = critQ.dequeue()
                print("Treating '%s' from Critical queue" % (patient))
                queuesState(critQ, serQ, fairQ)
            # if no patients, tell the user
            else:
                print("No patients in queue")
            
        # if treating serious queue
        elif (condition == "Serious"):
            # treat next patient in serious queue
            if(not serQ.isEmpty()):
                patient = serQ.dequeue()
                print("Treating '%s' from Serious queue" % (patient))
                queuesState(critQ, serQ, fairQ)
            # if no patients, tell the user
            else:
                print("No patients in queue")
            
        # if treating fair queue
        elif (condition == "Fair"):
            # treat next patient in fair queue
            if(not fairQ.isEmpty()):
                patient = fairQ.dequeue()
                print("Treating '%s' from Fair queue" % (patient))
                queuesState(critQ, serQ, fairQ)
            # if no patients, tell the user
            else:
                print("No patients in queue")

# %%
def exit():
    '''
    Exit and quit the program
    '''
    
    print()
    print("Exit")
    print()
    return

# %%
def queuesState(critQ, serQ, fairQ):
    '''
    print all of the queues
    '''
    print("Queues are:")
    print("Critical: %s" % (critQ))
    print("Serious:  %s" % (serQ))
    print("Fair:     %s" % (fairQ))

# %%
def main():
    
    # name of file
    fileName = "ERsim.txt"
    # initialize the three queues for the three types of patients
    critQ = Queue()
    serQ = Queue()
    fairQ = Queue()
    
    # function that runs through all the lines of the file and prints what happens
    readFile("ERsim.txt", critQ, serQ, fairQ)
    
if __name__ == "__main__":
    main()
# Out:
# Add patient Wayne,B. to Critical queue
#
# Queues are:
# Critical: ['Wayne,B.']
# Serious:  []
# Fair:     []
#
# Add patient Allen,B. to Serious queue
#
# Queues are:
# Critical: ['Wayne,B.']
# Serious:  ['Allen,B.']
# Fair:     []
#
# Add patient Kent,C. to Fair queue
#
# Queues are:
# Critical: ['Wayne,B.']
# Serious:  ['Allen,B.']
# Fair:     ['Kent,C.']
#
# Add patient Queen,O. to Critical queue
#
# Queues are:
# Critical: ['Queen,O.', 'Wayne,B.']
# Serious:  ['Allen,B.']
# Fair:     ['Kent,C.']
#
# Add patient Prince,D. to Serious queue
#
# Queues are:
# Critical: ['Queen,O.', 'Wayne,B.']
# Serious:  ['Prince,D.', 'Allen,B.']
# Fair:     ['Kent,C.']
#
# Add patient Jordan,H. to Fair queue
#
# Queues are:
# Critical: ['Queen,O.', 'Wayne,B.']
# Serious:  ['Prince,D.', 'Allen,B.']
# Fair:     ['Jordan,H.', 'Kent,C.']
#
# Treat next patient
#
# Treating 'Wayne,B.' from Critical queue
# Queues are:
# Critical: ['Queen,O.']
# Serious:  ['Prince,D.', 'Allen,B.']
# Fair:     ['Jordan,H.', 'Kent,C.']
#
# Treat next patient
#
# Treating 'Queen,O.' from Critical queue
# Queues are:
# Critical: []
# Serious:  ['Prince,D.', 'Allen,B.']
# Fair:     ['Jordan,H.', 'Kent,C.']
#
# Add patient Curry,A. to Fair queue
#
# Queues are:
# Critical: []
# Serious:  ['Prince,D.', 'Allen,B.']
# Fair:     ['Curry,A.', 'Jordan,H.', 'Kent,C.']
#
# Treat next patient
#
# Treating 'Allen,B.' from Serious queue
# Queues are:
# Critical: []
# Serious:  ['Prince,D.']
# Fair:     ['Curry,A.', 'Jordan,H.', 'Kent,C.']
#
# Treat next patient
#
# Treating 'Prince,D.' from Serious queue
# Queues are:
# Critical: []
# Serious:  []
# Fair:     ['Curry,A.', 'Jordan,H.', 'Kent,C.']
#
# Treat next patient
#
# Treating 'Kent,C.' from Fair queue
# Queues are:
# Critical: []
# Serious:  []
# Fair:     ['Curry,A.', 'Jordan,H.']
#
# Add patient Lance,D. to Critical queue
#
# Queues are:
# Critical: ['Lance,D.']
# Serious:  []
# Fair:     ['Curry,A.', 'Jordan,H.']
#
# Add patient Jones,J. to Serious queue
#
# Queues are:
# Critical: ['Lance,D.']
# Serious:  ['Jones,J.']
# Fair:     ['Curry,A.', 'Jordan,H.']
#
# Treat next patient
#
# Treating 'Lance,D.' from Critical queue
# Queues are:
# Critical: []
# Serious:  ['Jones,J.']
# Fair:     ['Curry,A.', 'Jordan,H.']
#
# Treat next patient
#
# Treating 'Jones,J.' from Serious queue
# Queues are:
# Critical: []
# Serious:  []
# Fair:     ['Curry,A.', 'Jordan,H.']
#
# Treat next patient
#
# Treating 'Jordan,H.' from Fair queue
# Queues are:
# Critical: []
# Serious:  []
# Fair:     ['Curry,A.']
#
# Add patient Queen,O. to Critical queue
#
# Queues are:
# Critical: ['Queen,O.']
# Serious:  []
# Fair:     ['Curry,A.']
#
# Add patient Jones,J. to Serious queue
#
# Queues are:
# Critical: ['Queen,O.']
# Serious:  ['Jones,J.']
# Fair:     ['Curry,A.']
#
# Add patient Lance,D. to Fair queue
#
# Queues are:
# Critical: ['Queen,O.']
# Serious:  ['Jones,J.']
# Fair:     ['Lance,D.', 'Curry,A.']
#
# Add patient Palmer,R. to Serious queue
#
# Queues are:
# Critical: ['Queen,O.']
# Serious:  ['Palmer,R.', 'Jones,J.']
# Fair:     ['Lance,D.', 'Curry,A.']
#
# Add patient Allen,B. to Critical queue
#
# Queues are:
# Critical: ['Allen,B.', 'Queen,O.']
# Serious:  ['Palmer,R.', 'Jones,J.']
# Fair:     ['Lance,D.', 'Curry,A.']
#
# Add patient Wayne,B. to Serious queue
#
# Queues are:
# Critical: ['Allen,B.', 'Queen,O.']
# Serious:  ['Wayne,B.', 'Palmer,R.', 'Jones,J.']
# Fair:     ['Lance,D.', 'Curry,A.']
#
# Treat next patient on Serious queue
#
# Treating 'Jones,J.' from Serious queue
# Queues are:
# Critical: ['Allen,B.', 'Queen,O.']
# Serious:  ['Wayne,B.', 'Palmer,R.']
# Fair:     ['Lance,D.', 'Curry,A.']
#
# Treat all patients
#
# Treating 'Queen,O.' from Critical queue
# Queues are:
# Critical: ['Allen,B.']
# Serious:  ['Wayne,B.', 'Palmer,R.']
# Fair:     ['Lance,D.', 'Curry,A.']
#
# Treating 'Allen,B.' from Critical queue
# Queues are:
# Critical: []
# Serious:  ['Wayne,B.', 'Palmer,R.']
# Fair:     ['Lance,D.', 'Curry,A.']
#
# Treating 'Palmer,R.' from Serious queue
# Queues are:
# Critical: []
# Serious:  ['Wayne,B.']
# Fair:     ['Lance,D.', 'Curry,A.']
#
# Treating 'Wayne,B.' from Serious queue
# Queues are:
# Critical: []
# Serious:  []
# Fair:     ['Lance,D.', 'Curry,A.']
#
# Treating 'Curry,A.' from Fair queue
# Queues are:
# Critical: []
# Serious:  []
# Fair:     ['Lance,D.']
#
# Treating 'Lance,D.' from Fair queue
# Queues are:
# Critical: []
# Serious:  []
# Fair:     []
#
# No patients in queues
#
# Treat next patient
#
# No patients in queues
#
# Exit
